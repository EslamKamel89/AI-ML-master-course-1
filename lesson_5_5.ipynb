# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
values = np.array([100,102,101,103])
x = np.arange(len(values))
pr(values, 'values')
pr(x , 'x')
# Out:
# +++++++++++++++++ values ++++++++++++++++++
# <class 'numpy.ndarray'>
# array([100, 102, 101, 103])
# -----
#
# +++++++++++++++++ x ++++++++++++++++++
# <class 'numpy.ndarray'>
# array([0, 1, 2, 3])
# -----

# %%
fig , axes = plt.subplots(figsize=(10,4))
axes.plot(x , values , marker='o')
axes.set_title('Normal Axis')
axes.set_ylim(0,120)
# Out:
# (0.0, 120.0)

# %%
fig , axes = plt.subplots(figsize=(10,4))
axes.plot(x , values , marker='o')
axes.set_ylim(98,104)
# Out:
# (98.0, 104.0)

# %%
from typing import cast

from matplotlib.axes import Axes


rng = np.random.default_rng(42)
data = rng.normal(0,1,1000)
fig , axes = plt.subplots(1,2 , figsize=(10,4))
axes = cast(list[Axes] , axes)
axes[0].hist(data , bins=5)
axes[0].set_title('Few bins')
axes[1].hist(data , bins=50)
axes[1].set_title('Many bins')
# Out:
# Text(0.5, 1.0, 'Many bins')
