# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng(42)
data = rng.normal(5,2,1000)
mean = np.mean(data)
pr(mean , 'mean')
variance = np.var(data)
pr(variance , 'variance')
std = np.std(data)
pr(std , 'std')
# Out:
# +++++++++++++++++ mean ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(4.942216898008106)
# -----
#
# +++++++++++++++++ variance ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(3.910287584243274)
# -----
#
# +++++++++++++++++ std ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(1.9774447107930158)
# -----
