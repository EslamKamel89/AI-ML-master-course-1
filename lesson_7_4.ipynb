# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng(42)
true_data = rng.normal(10,2 , 100000)
sample = true_data[:10]
mean = sample.mean()
pr(mean , 'mean')
big_sample = true_data[:1000]
mean = big_sample.mean()
pr(mean , 'mean')
# Out:
# +++++++++++++++++ mean ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(9.328857383188257)
# -----
#
# +++++++++++++++++ mean ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(9.942216898008107)
# -----
