# %%
from utils import pr
from utils import measure_time
import numpy as np

# %%
a = 1e16
b = a +1 
pr(b , 'b')
pr(b-a , 'b-a')
# Out:
# +++++++++++++++++ b ++++++++++++++++++
# <class 'float'>
# 1e+16
# -----
#
# +++++++++++++++++ b-a ++++++++++++++++++
# <class 'float'>
# 0.0
# -----
# 0.0

# %%
x = np.array([ 1e16 ,   1e16+1 ,  1e16+2, 1e16+3])
pr(x-1e16)
# Out:
# +++++++++++++++++++++++++++++++++++
# <class 'numpy.ndarray'>
# [0. 0. 2. 4.]
# -----
# array([0., 0., 2., 4.])

# %%
np.exp(1000)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_23056\2006519253.py:1: RuntimeWarning: overflow encountered in exp
#   np.exp(1000)
# np.float64(inf)
