# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.array([3,4])
b = np.array([1,0])
proj = (np.dot(a,b)/np.dot(b,b))*b
print( 'this is the project of a on b, but b is purely in the x axis\nso we basically removing the y component of a')
pr(proj )
# Out:
# this is the project of a on b, but b is purely in the x axis
# so we basically removing the y component of a
# +++++++++++++++++++++++++++++++++++
# <class 'numpy.ndarray'>
# array([3., 0.])
# -----
