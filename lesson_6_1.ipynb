# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lesson 6.1 — Vectors as Directions

# %%
import numpy as np
v = np.array([3, 4])
pr(v , 'v')
pr(v.shape , 'v.shape')
pr(np.linalg.norm(v) , 'norm v')
pr((3**2 + 4**2)**0.5 , 'norm calculated manually')
# Out:
# +++++++++++++++++ v ++++++++++++++++++
# <class 'numpy.ndarray'>
# array([3, 4])
# -----
#
# +++++++++++++++++ v.shape ++++++++++++++++++
# <class 'tuple'>
# (2,)
# -----
#
# +++++++++++++++++ norm v ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(5.0)
# -----
#
# +++++++++++++++++ norm calculated manually ++++++++++++++++++
# <class 'float'>
# 5.0
# -----
