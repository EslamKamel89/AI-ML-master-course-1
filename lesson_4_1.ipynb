# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/big.csv')
pr(df.head())
pr(df.shape)
# Out:
# +++++++++++++++++++++++++++++++++++
# <class 'pandas.DataFrame'>
#    id   name
# 0   1  Row 1
# 1   2  Row 2
# 2   3  Row 3
# 3   4  Row 4
# 4   5  Row 5
# -----
#
# +++++++++++++++++++++++++++++++++++
# <class 'tuple'>
# (1000000, 2)
# -----
