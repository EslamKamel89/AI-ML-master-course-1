# %%
from utils import pr
from utils import measure_time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.array([1,2])
b = np.array([3,4])
dot = np.dot(a,b)
pr(dot , 'dot')
dot = a @ b
pr(dot , 'dot')
# Out:
# +++++++++++++++++ dot ++++++++++++++++++
# <class 'numpy.int64'>
# np.int64(11)
# -----
#
# +++++++++++++++++ dot ++++++++++++++++++
# <class 'numpy.int64'>
# np.int64(11)
# -----
